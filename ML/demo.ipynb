# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('data.csv')
dataset.head(20)
# Out:
#       risk    income   roi points literacy      investin
# 0   Medium  3-5Lakhs   Low    6-8     high            FD
# 1   Medium  3-5Lakhs  High     >8      low  mutual funds
# 2   Medium   >5Lakhs   Low     >8      low        stocks
# 3   Medium   >5Lakhs  High    6-8     high        stocks
# 4   Medium   <3Lakhs   Med    6-8     high        stocks
# 5   Medium   <3Lakhs  High    6-8      low            FD
# 6   Medium   >5Lakhs   Med    3-5      med        stocks
# 7   Medium   >5Lakhs   Low    6-8      low            FD
# 8   Medium   >5Lakhs  High    6-8      med        stocks
# 9     High   <3Lakhs   Low    3-5      low  mutual funds
# 10  Medium  3-5Lakhs  High     >8     high            FD
# 11  Medium  3-5Lakhs  High     >8      med            FD
# 12  Medium   <3Lakhs  High    3-5     high        stocks
# 13  Medium   <3Lakhs  High    3-5      med        stocks
# 14  Medium   >5Lakhs  High    3-5      med            FD
# 15  Medium   <3Lakhs   Med    3-5      med        stocks
# 16  Medium   <3Lakhs   Low    3-5     high        stocks
# 17  Medium   <3Lakhs   Med     >8     high  mutual funds
# 18  Medium  3-5Lakhs  High    3-5     high  mutual funds
# 19  Medium   >5Lakhs   Low    3-5     high        stocks

# %%
#Encode the categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
dataset['risk']=labelencoder.fit_transform(dataset['risk'])

dataset.head(20)
# Out:
#     risk    income   roi points literacy      investin
# 0      2  3-5Lakhs   Low    6-8     high            FD
# 1      2  3-5Lakhs  High     >8      low  mutual funds
# 2      2   >5Lakhs   Low     >8      low        stocks
# 3      2   >5Lakhs  High    6-8     high        stocks
# 4      2   <3Lakhs   Med    6-8     high        stocks
# 5      2   <3Lakhs  High    6-8      low            FD
# 6      2   >5Lakhs   Med    3-5      med        stocks
# 7      2   >5Lakhs   Low    6-8      low            FD
# 8      2   >5Lakhs  High    6-8      med        stocks
# 9      0   <3Lakhs   Low    3-5      low  mutual funds
# 10     2  3-5Lakhs  High     >8     high            FD
# 11     2  3-5Lakhs  High     >8      med            FD
# 12     2   <3Lakhs  High    3-5     high        stocks
# 13     2   <3Lakhs  High    3-5      med        stocks
# 14     2   >5Lakhs  High    3-5      med            FD
# 15     2   <3Lakhs   Med    3-5      med        stocks
# 16     2   <3Lakhs   Low    3-5     high        stocks
# 17     2   <3Lakhs   Med     >8     high  mutual funds
# 18     2  3-5Lakhs  High    3-5     high  mutual funds
# 19     2   >5Lakhs   Low    3-5     high        stocks
